# %% [markdown]
# # PowerModels.jl: Load PSS/E RAW, Run Power Flow, and Compute PTDF
#
# 1. Load PSS/E RAW
# 2. Run AC LF
# 3. Run DC LF
# 4. Compute PTDF

# %%
using Pkg
Pkg.activate(".")
test_system_dir = "./Test System/" # The system path goes here
raw_path = test_system_dir * "SmallSystem_case.raw"
# Out:
#   Activating new project at `~/github/choose-solver`
# "./Test System/SmallSystem_case.raw"

# %% [markdown]
# ## 1. Load PSS/E RAW

# %%
using PowerModels, Ipopt
data = PowerModels.parse_file(raw_path; import_all=true)
# Out:
# [info | PowerModels]: The PSS(R)E parser currently supports buses, loads, shunts, generators, branches, transformers, and dc lines
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# ...
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## 2. Run AC Power Flow

# %%
@time begin
    # Method 1: AC power flow (Ipopt recommended)
    ac_pf = PowerModels.solve_ac_pf(data, Ipopt.Optimizer)
    # ac_pf
end
# Out:
# This is Ipopt version 3.14.19, running with linear solver MUMPS 5.8.1.
#
# Number of nonzeros in equality constraint Jacobian...:    98537
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   282390
#
# Total number of variables............................:    14708
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    14661
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.10e+01 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 8.38e+00 4.69e-01  -1.0 2.77e+01  -4.0 1.00e+00 1.00e+00h  1
#    2  0.0000000e+00 8.81e+00 7.62e-01  -1.0 2.55e+01  -4.5 1.00e+00 1.00e+00h  1
#    3  0.0000000e+00 1.46e-01 1.80e-02  -1.0 8.84e+00  -5.0 1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 7.22e-05 1.19e-05  -3.8 4.96e-02  -5.4 1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 2.85e-11 7.10e-11  -5.7 2.73e-05  -5.9 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   7.1032460319390317e-11    7.1032460319390317e-11
# Constraint violation....:   1.2563609007310017e-11    2.8518819250589186e-11
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   7.1032460319390317e-11    7.1032460319390317e-11
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.469
#
# EXIT: Optimal Solution Found.
#   2.162645 seconds (28.03 M allocations: 1.429 GiB, 29.29% gc time)
# Dict{String, Any} with 8 entries:
#   "solve_time"         => 0.868606
#   "optimizer"          => "Ipopt"
#   "termination_status" => LOCALLY_SOLVED
#   "dual_status"        => FEASIBLE_POINT
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 0.0
#   "solution"           => Dict{String, Any}("baseMVA"=>100.0, "gen"=>Dict{Strin…
#   "objective_lb"       => -Inf

# %%
@time begin
    # Method 2: AC power flow (Ipopt recommended)
    ac_pf = PowerModels.compute_ac_pf(data)
    # ac_pf
end
# Out:
#   0.156001 seconds (868.30 k allocations: 154.985 MiB)
# Dict{String, Any} with 5 entries:
#   "optimizer"          => "NLsolve"
#   "termination_status" => true
#   "objective"          => 0.0
#   "solution"           => Dict{String, Any}("gen"=>Dict{String, Any}("153"=>Dic…
#   "solve_time"         => 0.103268

# %% [markdown]
# ## 3. Run DC Power Flow

# %%
@time begin
    # DC power flow (linear approximation)
    dc_pf = PowerModels.solve_dc_pf(data, Ipopt.Optimizer)
    dc_pf
end
# Out:
# This is Ipopt version 3.14.19, running with linear solver MUMPS 5.8.1.
#
# Number of nonzeros in equality constraint Jacobian...:    25283
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:     7354
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     7354
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.10e+01 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.15e-12 0.00e+00  -1.0 2.77e+01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   9.1164905346197194e-14    2.1458390619955026e-12
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   9.1164905346197194e-14    2.1458390619955026e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total seconds in IPOPT                               = 0.012
#
# EXIT: Optimal Solution Found.
#   0.199127 seconds (2.98 M allocations: 133.109 MiB)
# Dict{String, Any} with 8 entries:
#   "solve_time"         => 0.0126069
#   "optimizer"          => "Ipopt"
#   "termination_status" => LOCALLY_SOLVED
#   "dual_status"        => FEASIBLE_POINT
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          =>
cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 252 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 660 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 462 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 127 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 633 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 177 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 254 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 693 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 242 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 396 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 260 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 495 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 680 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 35 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 131 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 365 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 691 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 494 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 556 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 139 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 413 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# ...
# [info | PowerModels]: updated generator 85 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 568 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 30 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 309 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 569 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 642 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 589 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 75 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 669 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 460 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 537 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 208 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 688 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 224 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 711 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 699 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 687 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 225 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 161 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 692 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 712 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 142 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 637 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 432 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 113 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 492 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 445 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 322 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 269 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 588 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 555 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 663 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 628 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 171 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 646 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 653 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 345 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 319 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 478 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 502 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 312 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 567 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 621 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 67 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 344 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 535 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 452 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 639 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 109 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 320 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 217 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 662 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 659 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 358 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 541 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 234 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 205 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 298 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 164 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 380 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 126 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 226 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 553 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 644 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 689 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 512 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 471 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 493 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 361 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 397 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 4 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 221 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 210 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 690 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 134 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 133 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 240 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 329 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 373 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 574 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 246 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 466 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 560 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 679 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 375 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 307 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 565 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 538 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 411 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 132 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 470 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 618 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 119 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 42 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 28 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 381 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 439 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 347 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 290 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 409 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 314 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 163 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 481 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 281 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 730 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 25 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 114 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 681 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 31 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 274 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 484 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 412 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 479 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 352 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 150 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 330 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 310 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 677 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 377 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 725 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 585 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 124 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 70 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 338 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 198 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 348 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 144 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 649 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 271 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 434 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 604 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 563 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 655 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 336 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 603 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 414 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 710 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: updated generator 306 cost function with order 2 to a function of order 3: [0.0, 100.0, 0.0]
# [info | PowerModels]: removed 94 inactive gen components
#   1.310057 seconds (2.30 M allocations: 2.272 GiB, 36.64% gc time)
# (9140, 6717)

# %% [markdown]
# ## 5. Run Contingency Sensitivity Computation
#
# Compute PTDF matrices for base case + 500 contingencies.
# This matches the configuration in the PowSyBl notebook (500 contingencies, 1000 monitored branches).

# %%
# Get network data
data = PowerModels.parse_file(raw_path; import_all=true)
basic = PowerModels.make_basic_network(data)

# Configuration matching PowSyBl notebook
num_contingencies = 500
num_monitored = 1000

# Get sorted branch IDs for deterministic selection
all_branch_ids = sort(collect(keys(basic["branch"])))
contingency_branches = all_branch_ids[1:min(num_contingencies, length(all_branch_ids))]
monitored_branches = all_branch_ids[1:min(num_monitored, length(all_branch_ids))]

println("Configuration:")
println("  Contingencies: $(length(contingency_branches))")
println("  Monitored branches: $(length(monitored_branches))")
# Out:
# [info | PowerModels]: The PSS(R)E parser currently supports buses, loads, shunts, generators, branches, transformers, and dc lines
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# ...
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# [warn | PowerModels]: The following fields in BRANCH are missing: O2, F2, O3, F3, O4, F4
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
@time begin
    # Compute PTDF for base case
    base_ptdf = PowerModels.calc_basic_ptdf_matrix(basic)
    
    # Compute PTDF for each contingency (using only 500 contingencies to match PowSyBl)
    successful = 0
    for (i, br_id) in enumerate(contingency_branches)
        try
            # Create contingency by disabling the branch
            basic_cont = deepcopy(basic)
            basic_cont["branch"][br_id]["br_status"] = 0  # outaged
            
            # Recompute PTDF for this contingency
            ptdf_cont = PowerModels.calc_basic_ptdf_matrix(basic_cont)
            successful += 1
        catch e
            # Some contingencies may cause infeasibility - this is expected
        end
    end
    println("Successfully computed PTDF for $successful/$(length(contingency_branches)) contingencies")
end
# Out:
# [error | PowerModels]: Failed factorization in calc_susceptance_matrix_inv
# Successfully computed PTDF for 499/500 contingencies
# 283.321727 seconds (415.89 M allocations: 1.083 TiB, 10.49% gc time, 0.00% compilation time)
